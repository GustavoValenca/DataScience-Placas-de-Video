# %% [markdown]
# # Web Scraping de Placas de Vídeo

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import re

# %% [markdown]
# ## Headers

# %%
headers = {
  'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"
}

# %% [markdown]
# ## Links das páginas

# %%
# Links contendo 20 placas de vídeo por página
links_kabum = [str("https://www.kabum.com.br/hardware/placa-de-video-vga?page_number={}&page_size=20&facet_filters=&sort=most_searched").format(i) for i in range(1, 64)]

# %% [markdown]
# ## Driver

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ## Listas com as features

# %%
price_list = []
gpu_list = []
brand_list = []
model_list = []
core_list = []
memory_size_list = []
memory_speed_list = []
memory_type_list = []
memory_interface_list = []
recommended_psu_list = []
garantia_list = []
peso_list = []

# %% [markdown]
# ## Verificando página por página

# %%
for link in links_kabum:
    req = requests.get(link, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    products = soup.find_all(class_ = 'productCard')

    for product in products:
        product_path = (product.find('a'))['href']
        product_link = str(f"https://www.kabum.com.br{product_path}")

        product_req = requests.get(product_link, headers=headers)
        product_soup = BeautifulSoup(product_req.text, 'html.parser')

        print("Link do produto: ")
        print(product_link)

        try:
            driver.get(product_link)
            info = driver.find_element(By.ID, "secaoInformacoesTecnicas")
        except:
            continue
        
        info_string = info.text

        # Preço:

        price = product_soup.find(class_ = 'finalPrice')
        if price != None:
            # Tratando o preço:

            price = str(price.text)[3:].split('.')
            
            # Preços de mil reais pra cima
            if len(price) > 1:
                price[1] = price[1].split(',')
                formatted_price = float(f"{price[0]}{price[1][0]}.{price[1][1]}")

            # Preços abaixo de mil reais
            else:
                price[0] = price[0].split(',')
                formatted_price = float(f"{price[0][0]}.{price[0][1]}")

            print(f"Preço: R${formatted_price}")
            price_list.append(formatted_price)
        else:
            # O produto não tem preço
            price_list.append("")

        # Flags
        found_gpu = False
        found_brand = False
        found_model = False
        found_core = False
        found_memory_size = False
        found_memory_speed = False
        found_memory_type = False
        found_memory_interface = False
        found_recommended_psu = False
        found_garantia = False
        found_peso = False

        # GPU
        title = str(product_soup.find(class_ = 'col-purchase').find('h1').text)
        if "AMD" in title or "Radeon" in title:
            gpu_list.append("AMD")
            found_gpu = True
        elif "NVIDIA" in title or "Nvidia" in title or "GeForce" in title or "Geforce" in title:
            gpu_list.append("NVIDIA")
            found_gpu = True
        elif "Intel" in title:
            gpu_list.append("Intel")
            found_gpu = True

        # Garantia
        position = info_string.find("Meses")
        if position == -1:   
            position = info_string.find("meses")

        if position != -1:
            garantia = info_string[position-3:position-1]
            try:
                garantia_list.append(int(garantia))
                found_garantia = True
                print(f"Meses de garantia: {garantia}")
            except:
                pass

        # Peso
        position = info_string.find("Gramas")
        if position == -1:   
            position = info_string.find("gramas")

        if position != -1:
            peso = info_string[position-5:position-1]
            try:
                peso_list.append(int(peso))
                found_peso = True
                print(f"Peso: {peso}")
            except:
                pass
        
        lines = info_string.split('\n')
        for line in lines:

            # Interface de Memória
            if found_memory_interface == False and ("bits" in line or "bit" in line or "Bits" in line):
                if "64" in line:
                    memory_interface_list.append(64)
                    found_memory_interface = True
                    print("Interface: 64")
                elif "128" in line:
                    memory_interface_list.append(128)
                    found_memory_interface = True
                    print("Interface: 128")
                elif "192" in line:
                    memory_interface_list.append(192)
                    found_memory_interface = True
                    print("Interface: 192")
                elif "256" in line:
                    memory_interface_list.append(256)
                    found_memory_interface = True
                    print("Interface: 256")
                elif "384" in line:
                    memory_interface_list.append(384)
                    found_memory_interface = True
                    print("Interface: 384")
                elif "512" in line:
                    memory_interface_list.append(512)
                    found_memory_interface = True
                    print("Interface: 512")
            
            # Tipo de Memória
            if found_memory_type == False:
                pattern = r'([gG][dD][dD][rR]\d[xX]?\s*$)|([gG][dD][dD][rR]\d[xX]?\s*\b)|([dD][dD][rR]\d[xX]?\s*$)|([dD][dD][rR]\d[xX]?\s*\b)'
                result = re.search(pattern, line)
                if result != None:
                    found_memory_type = True
                    memory_type_list.append(result.group())
                    print("Tipo da Memória: " + result.group())

            # Velocidade da Memória
            if found_memory_speed == False:
                pattern = r'\d{1,2}\s*[Gg]bps'
                result = re.search(pattern, line)
                if  result != None:
                    # [^0-9] signifca tudo que não for um dígito de 0 a 9
                    only_numbers = re.sub('[^0-9]', '', result.group())
                    memory_speed = int(only_numbers)
                    if memory_speed < 30:
                        memory_speed_list.append(memory_speed)
                        found_memory_speed = True
                        print("Velocidade da Memória: " + result.group())

            # Tamanho da Memória
            if found_memory_size == False:
                pattern = r'(\d{1,2}\s*[Gg][Bb]\s*$)|(\d{1,2}\s*[Gg][Bb]\s*\b)'
                result = re.search(pattern, line)
                if result != None:
                    only_numbers = re.sub('[^0-9]', '', result.group())
                    memory_size = int(only_numbers)
                    if memory_size < 49:
                        memory_size_list.append(memory_size)
                        found_memory_size = True
                        print("Tamanho da Memória: " + result.group())
            
            # Fonte Recomendada
            if found_recommended_psu == False and ("PSU" in line or "psu" in line or "Fonte" in line or "fonte" in line or "Alimentação" in line or "alimentação" in line or "Potência" in line or "potência" in line):
                pattern = r'(\d{3,4}\s*[wW]?\s*$)|(\d{3,4}\s*[wW]?\s*\b)'
                result = re.search(pattern, line)
                if result != None:
                    only_numbers = re.sub('[^0-9]', '', result.group())
                    recommended_psu = int(only_numbers)
                    recommended_psu_list.append(recommended_psu)
                    found_recommended_psu = True
                    print("Fonte Recomendada: " + result.group())

                else:
                    next_line = lines[lines.index(line) + 1]

                    pattern = r'(\d{3,4}\s*[wW]?\s*$)|(\d{3,4}\s*[wW]?\s*\b)'
                    result = re.search(pattern, next_line)

                    if result != None:
                        only_numbers = re.sub('[^0-9]', '', result.group())
                        recommended_psu = int(only_numbers)
                        recommended_psu_list.append(recommended_psu)
                        found_recommended_psu = True
                        print("Fonte Recomendada: " + result.group())        

            # Core
            if found_core == False and "Speed" not in line and "Mhz" not in line and "mhz" not in line and "Velocidade" not in line and "velocidade" not in line and ("Processador" in line or "CUDA" in line or "Cuda" in line or "Núcleos" in line or "Unidades" in line or "unidades" in line):
                only_numbers = re.sub('[^0-9]', '', line)
                if len(only_numbers) > 2:
                    core = int(only_numbers)
                    core_list.append(core)
                    found_core = True
                    print(f"Core: {core}")

                # Verifico se o dado está na outra linha
                elif len(only_numbers) == 0:
                    next_line = lines[lines.index(line) + 1]
                    only_numbers = re.sub('[^0-9]', '', next_line)
                    if len(only_numbers) > 2:
                        core = int(only_numbers)
                        core_list.append(core)
                        found_core = True
                        print(f"Core: {core}")

            # Marca
            if found_brand == False and "Marca" in line:
                brand = line[line.find("Marca")+6:].strip()
                brand_list.append(brand)
                found_brand = True
                print(f"Marca: {brand}")
            
            # Modelo
            if found_model == False and "Modelo" in line:
                model = line[line.find("Modelo")+7:].strip()
                model_list.append(model)
                found_model = True
                print(f"Modelo: {model}")

        # Adicionando vazio a features não encontradas
        if found_memory_interface == False: 
            memory_interface_list.append("")
        
        if found_memory_type == False:
            memory_type_list.append("")

        if found_memory_size == False:
            memory_size_list.append("")

        if found_memory_speed == False:
            memory_speed_list.append("")

        if found_recommended_psu == False:
            recommended_psu_list.append("")

        if found_core == False:
            core_list.append("")

        if found_gpu == False:
            gpu_list.append("")
        
        if found_garantia == False:
            garantia_list.append("")

        if found_peso == False:
            peso_list.append("")
        
        if found_brand == False:
            brand_list.append("")

        if found_model == False:
            model_list.append("")
# Out:
# Link do produto:
# https://www.kabum.com.br/produto/417853/placa-de-video-rx-6750-xt-mech-2x-12g-oc-msi-amd-12-gb-gddr6-xt-mech-2x-12g-oc
# Preço: R$2699.99
# Meses de garantia: 36
# Peso: 1474
# Marca: MSI
# Modelo: Radeon RX 6750 XT MECH 2X 12G OC
# Core: 2560
# Velocidade da Memória: 18 Gbps
# Tamanho da Memória: 12 GB
# Tipo da Memória: GDDR6
# Interface: 192
# Fonte Recomendada: 650W
# Link do produto:
# https://www.kabum.com.br/produto/164854/placa-de-video-rtx-3060-asus-dual-o12g-v2-nvidia-geforce-12gb-gddr6-lhr-dlss-ray-tracing-dual-rtx3060-o12g-v2
# Preço: R$2299.99
# Meses de garantia: 12
# Peso:
# 880
# Marca: ASUS
# Modelo: Dual RTX 3060 O12G V2
# Core: 3584
# Interface: 192
# Tamanho da Memória: 12GB
# Tipo da Memória: GDDR6
# Velocidade da Memória: 15 Gbps
# Fonte Recomendada: 650W
# Link do produto:
# https://www.kabum.com.br/produto/235984/placa-de-video-rx-6600-cld-8g-asrock-amd-radeon-8gb-gddr6-90-ga2rzz-00uanf
# Preço: R$1559.99
# Meses de garantia: 12
# Peso:
# 627
# Marca: ASRock
# Modelo: AMD Radeon RX 6600 CLD 8G
# Core: 1792
# Tamanho da Memória: 8GB
# Tipo da Memória: GDDR6
# Velocidade da Memória: 14 Gbps
# Interface: 128
# Fonte Recomendada: 500W
# Link do produto:
# https://www.kabum.com.br/produto/367414/placa-de-video-rtx-3050-xlr8-gaming-revel-epic-x-pny-geforce-8gb-gddr6-dlss-ray-tracing-vcg30508dfmpb
# Preço: R$1739.99
# Meses de garantia: 36
# Peso: 1052
# Marca: PNY
# Modelo: VCG30508DFMPB
# Core: 2560
# Tipo da Memória: GDDR6
# Tamanho da Memória: 8 GB
# Interface: 128
# Link do produto:
# https://www.kabum.com.br/produto/383616/placa-de-video-pny-nvidia-geforce-rtx-3060-12-gb-gddr6-dlss-ray-tracing-vcg306012dfbpb1
# Preço: R$2499.99
# Meses de garantia: 36
# Peso:
# 990
# Marca: PNY
# Modelo: VCG306012DFBPB1
# Core: 3584
# Velocidade da Memória: 15 Gbps
# Tipo da Memória: GDDR6
# Tamanho da Memória: 12 GB
# Interface: 192
# Link do produto:
# https://www.kabum.com.br/produto/384635/placa-de-video-rtx-3060-ti-dual-fan-pny-nvidia-geforce-8-gb-gddr6-lhr-dlss-ray-tracing-vcg3060t8ldfbpb1
# Preço: R$2799.99
# Meses de garantia: 36
# Peso:
# 990
# Marca: PNY
# Modelo: VCG3060T8LDFBPB1
# Core: 4864
# Velocidade da Memória: 14 Gbps
# Tamanho da Memória: 8 GB
# Tipo da Memória: GDDR6
# Interface: 256
# Link do produto:
# https://www.kabum.com.br/produto/108350/placa-de-video-gtx-1660-super-gaming-x-msi-nvidia-geforce-6gb-gddr6-geforce-gtx-1660-super-gaming-x
# Preço: R$1799.99
# Meses de garantia: 12
# Peso: 1576
# Marca: MSI
# Modelo: 1660 Super GAMING X
# Core: 1408
# Tamanho da Memória: 6GB
# Tipo da Memória: GDDR6
# Interface: 192
# Velocidade da Memória: 14 Gbps
# Fonte Recomendada: 125W
# Link do produto:
# https://www.kabum.com.br/produto/399026/placa-de-video-gtx-1650-pny-nvidia-geforce-single-fan-4-gb-gddr5-vcg16504d6sfmpb
# Preço: R$1029.99
# Meses de garantia: 36
# Peso:
# 989
# Marca: PNY
# Modelo: VCG16504D6SFMPB
# Core: 896
# Velocidade da Memória: 8 Gbps
# Tamanho da Memória: 4GB
# Tipo da Memória: GDDR5
# Interface: 128
# Fonte Recomendada: 300 W
# Link do produto:
# https://www.kabum.com.br/produto/384627/placa-de-video-rtx-3060-ventus-2x-msi-nvidia-geforce-12gb-gddr6-dlss-ray-tracing-rtx-3060-ventus-2x-12g-oc
# Preço: R$2234.99
# Meses de garantia: 12
# Peso: 1030
# Marca: MSI
# Modelo: RTX 3060 Ventus
# Core: 3584
# Velocidade da Memória: 15 Gbps
# Tamanho da Memória: 12 GB
# Tipo da Memória: GDDR6
# Interface: 192
# Fonte Recomendada: 550 W
# Link do produto:
# https://www.kabum.com.br/produto/270812/placa-de-video-gtx-1660-ti-o6g-evo-oc-asus-tuf-gaming-nvidia-geforce-6gb-gddr6-preto-tuf-gtx1660ti-o6g-evo-gaming
# Preço: R$1679.99
# Meses de garantia: 12
# Peso: 1070
# Marca: ASUS
# Modelo: TUF Gaming NVIDIA Geforce GTX 1660 TI O6G EVO OC
# Core: 1536
# Tipo da Memória: GDDR6
# Tamanho da Memória: 6GB
# Velocidade da Memória: 12 Gbps
# Interface: 192
# Fonte Recomendada: 450 W
# Link do produto:
# https://www.kabum.com.br/produto/180539/placa-de-video-rtx-3060-gaming-oc-gigabyte-geforce-12-gb-gddr6-lhr-ray-tracing-gv-n3060gaming-oc-12gd-rev-2-0-
# Preço: R$2793.99
# Meses de garantia: 12
# Peso: 1110
# Marca: Gigabyte
# Modelo: GV-N3060GAMING OC-12GD
# Core: 3584
# Interface: 192
# Tipo da Memória: GDDR6
# Tamanho da Memória: 12GB
# Fonte Recomendada: 550W
# Link do produto:
# https://www.kabum.com.br/produto/316908/placa-de-video-gtx-750-ti-duex-nvidia-geforce-2gb-gddr5-full-size-dxgtx750ti2gd5
# Preço: R$469.99
# Meses de garantia: 12
# Peso:
# 480
# Marca: Duex
# Modelo: DXGTX750TI2GD5
# Core: 640
# Tipo da Memória: GDDR5
# Interface: 128
# Link do produto:
# https://www.kabum.com.br/produto/308479/placa-de-video-rtx-3050-gaming-x-8g-msi-nvidia-geforce-8gb-gddr6-rgb-dlss-ray-tracing-geforce-rtx-3050-gaming-x-8g
# Preço: R$2561.99
# Meses de garantia: 12
# Peso: 1691
# Marca: MSI
# Modelo: RTX 3050 Gaming X 8G
# Core: 2560
# Velocidade da Memória: 14 Gbps
# Tipo da Memória: GDDR6
# Tamanho da Memória: 8GB
# Interface: 128
# Fonte Recomendada: 550 W
# Link do produto:
# https://www.kabum.com.br/produto/417543/placa-de-video-rtx-3060-verto-pny-nvidia-geforce-8-gb-gddr6-dlss-ray-tracing-vcg30608dfbpb1
# Preço: R$2158.99
# Meses de garantia: 36
# Peso: 1021
# Marca: PNY
# Modelo: VCG30608DFBPB1
# Core: 3584
# Velocidade da Memória: 15 Gbps
# Tamanho da Memória: 8 GB
# Tipo da Memória: GDDR6
# Interface: 128
# Fonte Recomendada: 550 W
# Link do produto:
# https://www.kabum.com.br/produto/191789/placa-de-video-rtx-3060-ti-1-click-oc-galax-nvidia-geforce-8gb-gddr6-lhr-dlss-ray-tracing-preto-36isl6md1vqw
# Preço: R$2829.99
# Meses de garantia: 12
# Peso: 1441
# Marca: Galax
# Modelo: 36ISL6MD1VQW
# Core: 4864
# Velocidade da Memória: 14 Gbps
# Tamanho da Memória: 8 GB
# Interface: 256
# Tipo da Memória: GDDR6
# Fonte Recomendada: 550 W
# Link do produto:
# https://www.kabum.com.br/produto/380802/placa-de-video-gtx-1630-ex-galax-nvidia-geforce-4-gb-gddr6-63nql4hp66ex
# Preço: R$878.99
# Meses de garantia: 24
# Peso:
# 961
# Marca: Galax
# Modelo: 63NQL4HP66EX
# Core: 512
# Velocidade da Memória: 12 Gbps
# Interface: 64
# Tipo da Memória: GDDR6
# Fonte Recomendada: 300W
# Tamanho da Memória: 4 GB
# Link do produto:
# https://www.kabum.com.br/produto/391124/placa-de-video-rtx-2060-ventus-msi-nvidia-geforce-12-gb-gddr6-ray-tracing-rtx-2060-ventus-12g-oc
# Preço: R$2199.99
# Meses de garantia: 36
# Peso: 1474
# Marca: MSI
# Modelo: GeForce RTX 2060 VENTUS 12G OC
# Core: 2176
# Velocidade da Memória: 14 Gbps
# Tamanho da Memória: 12 GB
# Tipo da Memória: GDDR6
# Interface: 192
# Fonte Recomendada: 500W
# Link do produto:
# https://www.kabum.com.br/produto/150657/placa-de-video-rtx-3060-1-click-oc-galax-geforce-12gb-gddr6-lhr-dlss-ray-tracing-36nol7md1voc
# Preço: R$2378.99
# Meses de garantia: 12
# Peso: 1419
# Marca: GALAX
# Modelo: 36NOL7MD1VOC
# Tipo da Memória: GDDR6
# Core: 3584
# Velocidade da Memória: 15 Gbps
# Tamanho da Memória: 12 GB
# Interface: 192
# Fonte Recomendada: 550 W
# Link do produto:
# https://www.kabum.com.br/produto/403365/placa-de-video-rtx-3060-ti-twin-edge-zotac-gaming-geforce-8-gb-gddr6x-led-dlss-ray-tracing-zt-a30620e-10p
# Preço: R$2999.99
# Meses de garantia: 24
# Peso: 2005
# Marca: Zotac
# Modelo: ZT-A30620E-10P
# Core: 4864
# Tamanho da Memória: 8GB
# Tipo da Memória: GDDR6X
# Interface: 256
# Velocidade da Memória: 19 Gbps
# Fonte Recomendada: 650W
# Link do produto:
# https://www.kabum.com.br/produto/404448/placa-de-video-rtx-3060-1-click-oc-pci-e-galax-8-gb-gddr6-128bit-36nsl8md6occ
# Preço: R$1979.99
# Meses de garantia: 12
# Peso: 4893
# Marca: Galax
# Modelo: 36NSL8MD6OCC
# Core: 3584
# Velocidade da Memória: 15 Gbps
# Tamanho da Memória: 8 GB
# Tipo da Memória: GDDR6
# Interface: 128
# Fonte Recomendada: 550 W

# %% [markdown]
# ## Criação do Data Frame

# %%
df = pd.DataFrame({"Preço":price_list, "Marca":brand_list, "Modelo":model_list, "GPU": gpu_list, "Unidades de Processamento":core_list, "Tamanho da Memória (GB)":memory_size_list, "Velocidade da Memória (Gbps)":memory_speed_list, "Tipo da Memória":memory_type_list, "Interface da Memória (Bits)":memory_interface_list ,"Fonte Recomendada (W)":recommended_psu_list, "Garantia (Meses)":garantia_list, "Peso":peso_list})

# %% [markdown]
# ### Exemplo gerado com apenas 1 página:

# %%
df
# Out:
#       Preço     Marca                                            Modelo
# 0   2699.99       MSI                  Radeon RX 6750 XT MECH 2X 12G OC  \
# 1   2299.99      ASUS                             Dual RTX 3060 O12G V2
# 2   1559.99    ASRock                         AMD Radeon RX 6600 CLD 8G
# 3   1739.99       PNY                                     VCG30508DFMPB
# 4   2499.99       PNY                                   VCG306012DFBPB1
# 5   2799.99       PNY                                  VCG3060T8LDFBPB1
# 6   1799.99       MSI                               1660 Super GAMING X
# 7   1029.99       PNY                                   VCG16504D6SFMPB
# 8   2234.99       MSI                                   RTX 3060 Ventus
# 9   1679.99      ASUS  TUF Gaming NVIDIA Geforce GTX 1660 TI O6G EVO OC
# 10  2793.99  Gigabyte                            GV-N3060GAMING OC-12GD
# 11   469.99      Duex                                    DXGTX750TI2GD5
# 12  2561.99       MSI                              RTX 3050 Gaming X 8G
# 13  2158.99       PNY                                    VCG30608DFBPB1
# 14  2829.99     Galax                                      36ISL6MD1VQW
# 15   878.99     Galax                                      63NQL4HP66EX
# 16  2199.99       MSI                    GeForce RTX 2060 VENTUS 12G OC
# 17  2378.99     GALAX                                      36NOL7MD1VOC
# 18  2999.99     Zotac                                    ZT-A30620E-10P
# 19  1979.99     Galax                                      36NSL8MD6OCC
#
#        GPU  Unidades de Processamento Tamanho da Memória (GB)
# 0      AMD                       2560                      12  \
# 1   NVIDIA                       3584                      12
# 2      AMD                       1792                       8
# 3   NVIDIA                       2560                       8
# 4   NVIDIA                       3584                      12
# 5   NVIDIA                       4864                       8
# 6   NVIDIA                       1408                       6
# 7   NVIDIA                        896                       4
# 8   NVIDIA                       3584                      12
# 9   NVIDIA                       1536                       6
# 10  NVIDIA                       3584                      12
# 11  NVIDIA                        640
# 12  NVIDIA                       2560                       8
# 13  NVIDIA                       3584                       8
# 14  NVIDIA                       4864                       8
# 15  NVIDIA                        512                       4
# 16  NVIDIA                       2176                      12
# 17  NVIDIA                       3584                      12
# 18  NVIDIA                       4864                       8
# 19                               3584                       8
#
#    Velocidade da Memória (Gbps) Tipo da Memória  Interface da Memória (Bits)
# 0                            18           GDDR6                          192  \
# 1                            15           GDDR6                          192
# 2                            14           GDDR6                          128
# 3                                         GDDR6                          128
# 4                            15           GDDR6                          192
# 5                            14           GDDR6                          256
# 6                            14           GDDR6                          192
# 7                             8           GDDR5                          128
# 8                            15           GDDR6                          192
# 9                            12           GDDR6                          192
# 10                                       GDDR6                           192
# 11                                        GDDR5                          128
# 12                           14           GDDR6                          128
# 13                           15           GDDR6                          128
# 14                           14          GDDR6                           256
# 15                           12          GDDR6                            64
# 16                           14           GDDR6                          192
# 17                           15           GDDR6                          192
# 18                           19          GDDR6X                          256
# 19                           15           GDDR6                          128
#
#    Fonte Recomendada (W)  Garantia (Meses)  Peso
# 0                    650                36  1474
# 1                    650                12   880
# 2                    500                12   627
# 3                                       36  1052
# 4                                       36   990
# 5                                       36   990
# 6                    125                12  1576
# 7                    300                36   989
# 8                    550                12  1030
# 9                    450                12  1070
# 10                   550                12  1110
# 11                                      12   480
# 12                   550                12  1691
# 13                   550                36  1021
# 14                   550                12  1441
# 15                   300                24   961
# 16                   500                36  1474
# 17                   550                12  1419
# 18                   650                24  2005
# 19                   550                12  4893

# %% [markdown]
# ## Exportando para CSV

# %%
df.to_csv('placas_de_video_kabum_RAW.csv')
